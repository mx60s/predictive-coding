# %%
# Need to rerun autoencoder on correct data

import math
import torch
import matplotlib.pyplot as plt
import numpy as np

import torchvision

from torch.utils.data import TensorDataset, DataLoader, random_split

#from tqdm.autonotebook import tqdm, trange

from utils.models import *
from utils.model_tools import *
import os; os.environ['TF_CPP_MIN_LOG_LEVEL'] = '1'

# %%
device = "cuda:1" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")

# !pwd
! echo $CONDA_PREFIX
# Out:
# Using cuda:1 device
# /home/mag/predictive-coding-thesis/src
# /home/mag/miniconda3/envs/predictive-code

# %% [markdown]
# ### Training the Predictive Coder model

# %%
# downsampling to 64x64

downsample = True

if downsample:
    import cv2
    data_dir = 'data/continuous-valid'
    prefix = 'frames' 
    for filename in os.listdir(data_dir):
        if filename.startswith(prefix) and not os.path.isdir(filename):
            frames_path = os.path.join(data_dir, filename)
            frames = np.load(frames_path)
            downsampled_images = []

            for frame in frames:
                resized_img = cv2.resize(frame, (64, 64), interpolation=cv2.INTER_AREA)
                downsampled_images.append(resized_img)
    
            downsampled_stack = np.stack(downsampled_images, axis=0)
            np.save(frames_path, downsampled_stack)

# %%
# preprocess data by removing consecutive repeat frames
remove_repeats = False

if remove_repeats:
    from utils.data_processing import remove_consecutive_repeats
    
    data_dir = 'data/continuous-face-north'
    prefix = 'coords' 
    for filename in os.listdir(data_dir):
        if filename.startswith(prefix):
            file_suffix = filename[len(prefix):]
            coords_path = os.path.join(data_dir, filename)
            frames_path = os.path.join(data_dir, 'frames' + file_suffix)
            
            kept_idx = remove_consecutive_repeats(coords_path)
            
            coords = np.load(coords_path)
            frames = np.load(frames_path)
            np.save(coords_path, coords[kept_idx])
            np.save(frames_path, frames[kept_idx])
            print(f'removed {len(coords) - len(kept_idx)} from {filename}')
            
            del coords
            del frames

# %%
torch.manual_seed(321)

transform = torchvision.transforms.Compose([
        torchvision.transforms.ToTensor(),
])

data_dir = 'data/detached'

dataset = AutoencoderDataset(source_directory=data_dir, 
                                 transform=transform, num_samples=100000)

train_ratio = math.floor(len(dataset) * 0.9)
train_data, test_data = random_split(dataset, [train_ratio, len(dataset) - train_ratio])
print(f'{train_ratio} training samples')

batch_size = 128
train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True, num_workers=2)
test_loader = DataLoader(test_data, batch_size=batch_size, shuffle=True, num_workers=2)
# Out:
# 90000 training samples

# %%
# Take a look at the sequence of images

def imshow(img):
   # img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

seq = next(iter(train_loader))
print(seq.shape)
imshow(torchvision.utils.make_grid(seq))
# Out:
# torch.Size([128, 3, 64, 64])

# %%
model = AutoEncoder()
model.to(device)
print(len(train_loader))

num_epochs = 200
steps_per_epoch = len(train_loader) #?

learning_rate = 0.1
weight_decay = 5 * 10**-6

loss_fn = torch.nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9, weight_decay=weight_decay, nesterov=True)
lr_scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer, learning_rate, epochs=num_epochs, steps_per_epoch=steps_per_epoch)
# Out:
# 704

# %%
model_file = f'model_files/autoencoder-continuous-detach_{train_ratio}_samples-{num_epochs}ep.pt'
train_losses_file = f'logs/autoencoder-continuous-detach-ep{num_epochs}-train_{train_ratio}txt'
test_losses_file = f'logs/autoencoder-continuous-detach-ep{num_epochs}-test_{train_ratio}.txt'

train_losses = []
test_losses = []

try:
    for epoch in range(num_epochs):
        print(f"Epoch {epoch+1}\n-------------------------------")
        train_loss = train_no_pred(train_loader, model, loss_fn, optimizer, device)
        test_loss = test_no_pred(test_loader, model, loss_fn, device)
        train_losses.append(train_loss)
        test_losses.append(test_loss)
    
        lr_scheduler.step()

        if epoch % 50 == 0:
            state = {
                'epoch': epoch + 1,  # Save next epoch number since current one is completed
                'state_dict': model.state_dict(),
                'optimizer': optimizer.state_dict(),
                'loss_history': test_losses,
              }
        
            model_checkpoint = f'model_files/autoencoder-continuous-detach_{train_ratio}_samples-{epoch}ep.pth'
            torch.save(state, model_checkpoint)

finally:
    torch.save(model.state_dict(), model_file)
    
    with open(train_losses_file, 'w') as fp:
        for s in train_losses:
            fp.write("%s\n" % s)
            
    with open(test_losses_file, 'w') as fp:
        for x in test_losses:
            fp.write("%s\n" % x)

    print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 0.155171  [    0/90000]
# Test Error:
#  Avg loss: 0.012708
#
# Epoch 2
# -------------------------------
# loss: 0.012454  [    0/90000]
# Test Error:
#  Avg loss: 0.010232
#
# Epoch 3
# -------------------------------
# loss: 0.011394  [    0/90000]
# Test Error:
#  Avg loss: 0.009152
#
# Epoch 4
# -------------------------------
# loss: 0.008581  [    0/90000]
# Test Error:
#  Avg loss: 0.008312
#
# Epoch 5
# -------------------------------
# loss: 0.009168  [    0/90000]
# Test Error:
#  Avg loss: 0.007882
#
# Epoch 6
# -------------------------------
# loss: 0.007583  [    0/90000]
# Test Error:
#  Avg loss: 0.007428
#
# Epoch 7
# -------------------------------
# loss: 0.007277  [    0/90000]
# Test Error:
#  Avg loss: 0.007197
#
# Epoch 8
# -------------------------------
# loss: 0.006744  [    0/90000]
# Test Error:
#  Avg loss: 0.006947
#
# Epoch 9
# -------------------------------
# loss: 0.006764  [    0/90000]
# Test Error:
#  Avg loss: 0.006703
#
# Epoch 10
# -------------------------------
# loss: 0.006769  [    0/90000]
# Test Error:
#  Avg loss: 0.006511
#
# Epoch 11
# -------------------------------
# loss: 0.006327  [    0/90000]
# Test Error:
#  Avg loss: 0.006403
#
# Epoch 12
# -------------------------------
# loss: 0.007155  [    0/90000]
# Test Error:
#  Avg loss: 0.006018
#
# Epoch 15
# -------------------------------
# loss: 0.005087  [    0/90000]
# Test Error:
#  Avg loss: 0.005922
#
# Epoch 16
# -------------------------------
# loss: 0.005484  [    0/90000]
# Test Error:
#  Avg loss: 0.005834
#
# Epoch 17
# -------------------------------
# loss: 0.006689  [    0/90000]
# Test Error:
#  Avg loss: 0.005755
#
# Epoch 18
# -------------------------------
# loss: 0.005974  [    0/90000]
# Test Error:
#  Avg loss: 0.005691
#
# Epoch 19
# -------------------------------
# loss: 0.005407  [    0/90000]
# Test Error:
#  Avg loss: 0.005607
#
# Epoch 20
# -------------------------------
# loss: 0.004824  [    0/90000]
# Test Error:
#  Avg loss: 0.005647
#
# Epoch 21
# -------------------------------
# loss: 0.005773  [    0/90000]
# Test Error:
#  Avg loss: 0.005445
#
# Epoch 22
# -------------------------------
# loss: 0.005532  [    0/90000]
# Test Error:
#  Avg loss: 0.005450
#
# Epoch 23
# -------------------------------
# loss: 0.005355  [    0/90000]
# Test Error:
#  Avg loss: 0.005381
#
# Epoch 24
# -------------------------------
# loss: 0.005370  [    0/90000]
# Test Error:
#  Avg loss: 0.005324
#
# Epoch 25
# -------------------------------
# loss: 0.005838  [    0/90000]
# Test Error:
#  Avg loss: 0.005267
#
# Epoch 26
# -------------------------------
# loss: 0.005630  [    0/90000]
# Test Error:
#  Avg loss: 0.005203
#
# Epoch 27
# -------------------------------
# loss: 0.005789  [    0/90000]
# Test Error:
#  Avg loss: 0.005189
#
# Epoch 28
# -------------------------------
# loss: 0.004983  [    0/90000]
# Test Error:
#  Avg loss: 0.005125
#
# Epoch 29
# -------------------------------
# loss: 0.004967  [    0/90000]
# Test Error:
#  Avg loss: 0.005254
#
# Epoch 30
# -------------------------------
# loss: 0.005206  [    0/90000]
# Test Error:
#  Avg loss: 0.005021
#
# Epoch 31
# -------------------------------
# loss: 0.004799  [    0/90000]
# Test Error:
#  Avg loss: 0.005016
#
# Epoch 32
# -------------------------------
# loss: 0.005014  [    0/90000]
# Test Error:
#  Avg loss: 0.004959
#
# Epoch 33
# -------------------------------
# loss: 0.005244  [    0/90000]
# Test Error:
#  Avg loss: 0.004966
#
# Epoch 34
# -------------------------------
# loss: 0.005122  [    0/90000]
# Test Error:
#  Avg loss: 0.004888
#
# Epoch 35
# -------------------------------
# loss: 0.004896  [    0/90000]
# Test Error:
#  Avg loss: 0.004879
#
# Epoch 36
# -------------------------------
# loss: 0.005232  [    0/90000]
# Test Error:
#  Avg loss: 0.004851
#
# Epoch 37
# -------------------------------
# loss: 0.004908  [    0/90000]
# Test Error:
#  Avg loss: 0.004806
#
# Epoch 38
# -------------------------------
# loss: 0.004566  [    0/90000]
# Test Error:
#  Avg loss: 0.004826
#
# Epoch 39
# -------------------------------
# loss: 0.004783  [    0/90000]
# Test Error:
#  Avg loss: 0.004774
#
# Epoch 40
# -------------------------------
# loss: 0.004272  [    0/90000]
# Test Error:
#  Avg loss: 0.004778
#
# Epoch 41
# -------------------------------
# loss: 0.004487  [    0/90000]
# Test Error:
#  Avg loss: 0.004682
#
# Epoch 42
# -------------------------------
# loss: 0.004306  [    0/90000]
# Test Error:
#  Avg loss: 0.004693
#
# Epoch 43
# -------------------------------
# loss: 0.004436  [    0/90000]
# Test Error:
#  Avg loss: 0.004720
#
# Epoch 44
# -------------------------------
# loss: 0.004099  [    0/90000]
# Test Error:
#  Avg loss: 0.004632
#
# Epoch 45
# -------------------------------
# loss: 0.005087  [    0/90000]
# Test Error:
#  Avg loss: 0.004635
#
# Epoch 46
# -------------------------------
# loss: 0.004857  [    0/90000]
# Test Error:
#  Avg loss: 0.004565
#
# Epoch 47
# -------------------------------
# loss: 0.004501  [    0/90000]
# Test Error:
#  Avg loss: 0.004566
#
# Epoch 48
# -------------------------------
# loss: 0.004314  [    0/90000]
# Test Error:
#  Avg loss: 0.004525
#
# Epoch 49
# -------------------------------
# loss: 0.004266  [    0/90000]
# Test Error:
#  Avg loss: 0.004484
#
# Epoch 50
# -------------------------------
# loss: 0.004535  [    0/90000]
# Test Error:
#  Avg loss: 0.004642
#
# Epoch 51
# -------------------------------
# loss: 0.004457  [    0/90000]
# Test Error:
#  Avg loss: 0.004494
#
# Epoch 52
# -------------------------------
# loss: 0.004411  [    0/90000]
# Test Error:
#  Avg loss: 0.004433
#
# Epoch 53
# -------------------------------
# loss: 0.004309  [    0/90000]
# Test Error:
#  Avg loss: 0.004429
#
# Epoch 54
# -------------------------------
# loss: 0.004139  [    0/90000]
# Test Error:
#  Avg loss: 0.004410
#
# Epoch 55
# -------------------------------
# loss: 0.004604  [    0/90000]
# Test Error:
#  Avg loss: 0.004392
#
# Epoch 56
# -------------------------------
# loss: 0.004046  [    0/90000]
# Test Error:
#  Avg loss: 0.004383
#
# Epoch 57
# -------------------------------
# loss: 0.004548  [    0/90000]
# Test Error:
#  Avg loss: 0.004324
#
# Epoch 58
# -------------------------------
# loss: 0.004268  [    0/90000]
# Test Error:
#  Avg loss: 0.004331
#
# Epoch 59
# -------------------------------
# loss: 0.004079  [    0/90000]
# Test Error:
#  Avg loss: 0.004306
#
# Epoch 60
# -------------------------------
# loss: 0.004334  [    0/90000]
# Test Error:
#  Avg loss: 0.004297
#
# Epoch 61
# -------------------------------
# loss: 0.003952  [    0/90000]
# Test Error:
#  Avg loss: 0.004275
#
# Epoch 62
# -------------------------------
# loss: 0.003942  [    0/90000]
# Test Error:
#  Avg loss: 0.004268
#
# Epoch 63
# -------------------------------
# loss: 0.003935  [    0/90000]
# Test Error:
#  Avg loss: 0.004256
#
# Epoch 64
# -------------------------------
# loss: 0.004709  [    0/90000]
# Test Error:
#  Avg loss: 0.004223
#
# Epoch 65
# -------------------------------
# loss: 0.003790  [    0/90000]
# Test Error:
#  Avg loss: 0.004226
#
# Epoch 66
# -------------------------------
# loss: 0.004221  [    0/90000]
# Test Error:
#  Avg loss: 0.004214
#
# Epoch 67
# -------------------------------
# loss: 0.004327  [    0/90000]
# Test Error:
#  Avg loss: 0.004174
#
# Epoch 68
# -------------------------------
# loss: 0.004380  [    0/90000]
# Test Error:
#  Avg loss: 0.004167
#
# Epoch 69
# -------------------------------
# loss: 0.003748  [    0/90000]
# Test Error:
#  Avg loss: 0.004145
#
# Epoch 70
# -------------------------------
# loss: 0.003624  [    0/90000]
# Test Error:
#  Avg loss: 0.004154
#
# Epoch 71
# -------------------------------
# loss: 0.003906  [    0/90000]
# Test Error:
#  Avg loss: 0.004127
#
# Epoch 72
# -------------------------------
# loss: 0.003843  [    0/90000]
# Test Error:
#  Avg loss: 0.004095
#
# Epoch 73
# -------------------------------
# loss: 0.004030  [    0/90000]
# Test Error:
#  Avg loss: 0.004103
#
# Epoch 74
# -------------------------------
# loss: 0.004042  [    0/90000]
# Test Error:
#  Avg loss: 0.004072
#
# Epoch 75
# -------------------------------
# loss: 0.004183  [    0/90000]
# Test Error:
#  Avg loss: 0.004089
#
# Epoch 76
# -------------------------------
# loss: 0.003793  [    0/90000]
# Test Error:
#  Avg loss: 0.004068
#
# Epoch 77
# -------------------------------
# loss: 0.003882  [    0/90000]
# Test Error:
#  Avg loss: 0.004106
#
# Epoch 78
# -------------------------------
# loss: 0.003937  [    0/90000]
# Test Error:
#  Avg loss: 0.004035
#
# Epoch 79
# -------------------------------
# loss: 0.003833  [    0/90000]
# Test Error:
#  Avg loss: 0.004086
#
# Epoch 80
# -------------------------------
# loss: 0.003908  [    0/90000]
# Test Error:
#  Avg loss: 0.004063
#
# Epoch 81
# -------------------------------
# loss: 0.004193  [    0/90000]
# Test Error:
#  Avg loss: 0.004002
#
# Epoch 82
# -------------------------------
# loss: 0.003913  [    0/90000]
# Test Error:
#  Avg loss: 0.004022
#
# Epoch 83
# -------------------------------
# loss: 0.004131  [    0/90000]
# Test Error:
#  Avg loss: 0.003988
#
# Epoch 84
# -------------------------------
# loss: 0.003752  [    0/90000]
# Test Error:
#  Avg loss: 0.004004
#
# Epoch 85
# -------------------------------
# loss: 0.004167  [    0/90000]
# Test Error:
#  Avg loss: 0.003984
#
# Epoch 86
# -------------------------------
# loss: 0.003885  [    0/90000]
# Test Error:
#  Avg loss: 0.003947
#
# Epoch 87
# -------------------------------
# loss: 0.003765  [    0/90000]
# Test Error:
#  Avg loss: 0.003932
#
# Epoch 88
# -------------------------------
# loss: 0.003172  [    0/90000]
# Test Error:
#  Avg loss: 0.003957
#
# Epoch 89
# -------------------------------
# loss: 0.003912  [    0/90000]
# Test Error:
#  Avg loss: 0.003936
#
# Epoch 90
# -------------------------------
# loss: 0.003517  [    0/90000]
# Test Error:
#  Avg loss: 0.003916
#
# Epoch 91
# -------------------------------
# loss: 0.004007  [    0/90000]
# Test Error:
#  Avg loss: 0.003922
#
# Epoch 92
# -------------------------------
# loss: 0.004183  [    0/90000]
# Test Error:
#  Avg loss: 0.003908
#
# Epoch 93
# -------------------------------
# loss: 0.003708  [    0/90000]
# Test Error:
#  Avg loss: 0.003891
#
# Epoch 94
# -------------------------------
# loss: 0.003851  [    0/90000]
# Test Error:
#  Avg loss: 0.003871
#
# Epoch 95
# -------------------------------
# loss: 0.003402  [    0/90000]
# Test Error:
#  Avg loss: 0.003861
#
# Epoch 96
# -------------------------------
# loss: 0.003534  [    0/90000]
# Test Error:
#  Avg loss: 0.003850
#
# Epoch 97
# -------------------------------
# loss: 0.004005  [    0/90000]
# Test Error:
#  Avg loss: 0.003844
#
# Epoch 98
# -------------------------------
# loss: 0.003428  [    0/90000]
# Test Error:
#  Avg loss: 0.003823
#
# Epoch 99
# -------------------------------
# loss: 0.003356  [    0/90000]
# Test Error:
#  Avg loss: 0.003810
#
# Epoch 100
# -------------------------------
# loss: 0.003265  [    0/90000]
# Test Error:
#  Avg loss: 0.003861
#
# Epoch 101
# -------------------------------
# loss: 0.003466  [    0/90000]
# Test Error:
#  Avg loss: 0.003810
#
# Epoch 102
# -------------------------------
# loss: 0.003735  [    0/90000]
# Test Error:
#  Avg loss: 0.003826
#
# Epoch 103
# -------------------------------
# loss: 0.003498  [    0/90000]
# Test Error:
#  Avg loss: 0.003786
#
# Epoch 104
# -------------------------------
# loss: 0.003503  [    0/90000]
# Test Error:
#  Avg loss: 0.003789
#
# Epoch 105
# -------------------------------
# loss: 0.003344  [    0/90000]
# Test Error:
#  Avg loss: 0.003782
#
# Epoch 106
# -------------------------------
# loss: 0.003709  [    0/90000]
# Test Error:
#  Avg loss: 0.003774
#
# Epoch 107
# -------------------------------
# loss: 0.003680  [    0/90000]
# Test Error:
#  Avg loss: 0.003776
#
# Epoch 108
# -------------------------------
# loss: 0.003374  [    0/90000]
# Test Error:
#  Avg loss: 0.003770
#
# Epoch 109
# -------------------------------
# loss: 0.003573  [    0/90000]
# Test Error:
#  Avg loss: 0.003743
#
# Epoch 110
# -------------------------------
# loss: 0.003490  [    0/90000]
# Test Error:
#  Avg loss: 0.003739
#
# Epoch 111
# -------------------------------
# loss: 0.003581  [    0/90000]
# Test Error:
#  Avg loss: 0.003734
#
# Epoch 112
# -------------------------------
# loss: 0.003628  [    0/90000]
# Test Error:
#  Avg loss: 0.003732
#
# Epoch 113
# -------------------------------
# loss: 0.003655  [    0/90000]
# Test Error:
#  Avg loss: 0.003708
#
# Epoch 114
# -------------------------------
# loss: 0.003694  [    0/90000]
# Test Error:
#  Avg loss: 0.003691
#
# Epoch 115
# -------------------------------
# loss: 0.003340  [    0/90000]
# Test Error:
#  Avg loss: 0.003718
#
# Epoch 116
# -------------------------------
# loss: 0.003423  [    0/90000]
# Test Error:
#  Avg loss: 0.003695
#
# Epoch 117
# -------------------------------
# loss: 0.003472  [    0/90000]
# Test Error:
#  Avg loss: 0.003697
#
# Epoch 118
# -------------------------------
# loss: 0.003700  [    0/90000]
# Test Error:
#  Avg loss: 0.003683
#
# Epoch 119
# -------------------------------
# loss: 0.003306  [    0/90000]
# Test Error:
#  Avg loss: 0.003660
#
# Epoch 120
# -------------------------------
# loss: 0.003751  [    0/90000]
# Test Error:
#  Avg loss: 0.003682
#
# Epoch 121
# -------------------------------
# loss: 0.003638  [    0/90000]
# Test Error:
#  Avg loss: 0.003681
#
# Epoch 122
# -------------------------------
# loss: 0.003589  [    0/90000]
# Test Error:
#  Avg loss: 0.003670
#
# Epoch 123
# -------------------------------
# loss: 0.003225  [    0/90000]
# Test Error:
#  Avg loss: 0.003654
#
# Epoch 124
# -------------------------------
# loss: 0.003800  [    0/90000]
# Test Error:
#  Avg loss: 0.003641
#
# Epoch 125
# -------------------------------
# loss: 0.003608  [    0/90000]
# Test Error:
#  Avg loss: 0.003633
#
# Epoch 126
# -------------------------------
# loss: 0.003388  [    0/90000]
# Test Error:
#  Avg loss: 0.003623
#
# Epoch 127
# -------------------------------
# loss: 0.003752  [    0/90000]
# Test Error:
#  Avg loss: 0.003663
#
# Epoch 128
# -------------------------------
# loss: 0.003301  [    0/90000]
# Test Error:
#  Avg loss: 0.003619
#
# Epoch 129
# -------------------------------
# loss: 0.002968  [    0/90000]
# Test Error:
#  Avg loss: 0.003639
#
# Epoch 130
# -------------------------------
# loss: 0.003478  [    0/90000]
# Test Error:
#  Avg loss: 0.003618
#
# Epoch 131
# -------------------------------
# loss: 0.003142  [    0/90000]
# Test Error:
#  Avg loss: 0.003588
#
# Epoch 132
# -------------------------------
# loss: 0.003008  [    0/90000]
# Test Error:
#  Avg loss: 0.003604
#
# Epoch 133
# -------------------------------
# loss: 0.002993  [    0/90000]
# Test Error:
#  Avg loss: 0.003593
#
# Epoch 134
# -------------------------------
# loss: 0.003161  [    0/90000]
# Test Error:
#  Avg loss: 0.003607
#
# Epoch 135
# -------------------------------
# loss: 0.003745  [    0/90000]
# Test Error:
#  Avg loss: 0.003575
#
# Epoch 136
# -------------------------------
# loss: 0.002955  [    0/90000]
# Test Error:
#  Avg loss: 0.003587
#
# Epoch 137
# -------------------------------
# loss: 0.003448  [    0/90000]
# Test Error:
#  Avg loss: 0.003571
#
# Epoch 138
# -------------------------------
# loss: 0.002985  [    0/90000]
# Test Error:
#  Avg loss: 0.003559
#
# Epoch 139
# -------------------------------
# loss: 0.003350  [    0/90000]
# Test Error:
#  Avg loss: 0.003548
#
# Epoch 140
# -------------------------------
# loss: 0.003215  [    0/90000]
# Test Error:
#  Avg loss: 0.003547
#
# Epoch 141
# -------------------------------
# loss: 0.003266  [    0/90000]
# Test Error:
#  Avg loss: 0.003565
#
# Epoch 142
# -------------------------------
# loss: 0.003155  [    0/90000]
# Test Error:
#  Avg loss: 0.003564
#
# Epoch 143
# -------------------------------
# loss: 0.003330  [    0/90000]
# Test Error:
#  Avg loss: 0.003522
#
# Epoch 144
# -------------------------------
# loss: 0.003265  [    0/90000]
# Test Error:
#  Avg loss: 0.003518
#
# Epoch 145
# -------------------------------
# loss: 0.003004  [    0/90000]
# Test Error:
#  Avg loss: 0.003502
#
# Epoch 146
# -------------------------------
# loss: 0.003143  [    0/90000]
# Test Error:
#  Avg loss: 0.003545
#
# Epoch 147
# -------------------------------
# loss: 0.003662  [    0/90000]
# Test Error:
#  Avg loss: 0.003503
#
# Epoch 148
# -------------------------------
# loss: 0.003613  [    0/90000]
# Test Error:
#  Avg loss: 0.003507
#
# Epoch 149
# -------------------------------
# loss: 0.003024  [    0/90000]
# Test Error:
#  Avg loss: 0.003510
#
# Epoch 150
# -------------------------------
# loss: 0.003391  [    0/90000]
# Test Error:
#  Avg loss: 0.003498
#
# Epoch 151
# -------------------------------
# loss: 0.003739  [    0/90000]
# Test Error:
#  Avg loss: 0.003550
#
# Epoch 152
# -------------------------------
# loss: 0.003159  [    0/90000]
# Test Error:
#  Avg loss: 0.003461
#
# Epoch 153
# -------------------------------
# loss: 0.003321  [    0/90000]
# Test Error:
#  Avg loss: 0.003469
#
# Epoch 154
# -------------------------------
# loss: 0.003176  [    0/90000]
# Test Error:
#  Avg loss: 0.003461
#
# Epoch 155
# -------------------------------
# loss: 0.003135  [    0/90000]
# Test Error:
#  Avg loss: 0.003493
#
# Epoch 156
# -------------------------------
# loss: 0.003559  [    0/90000]
# Test Error:
#  Avg loss: 0.003517
#
# Epoch 157
# -------------------------------
# loss: 0.003291  [    0/90000]
# Test Error:
#  Avg loss: 0.003469
#
# Epoch 158
# -------------------------------
# loss: 0.003355  [    0/90000]
# Test Error:
#  Avg loss: 0.003455
#
# Epoch 159
# -------------------------------
# loss: 0.003532  [    0/90000]
# Test Error:
#  Avg loss: 0.003455
#
# Epoch 160
# -------------------------------
# loss: 0.003529  [    0/90000]
# Test Error:
#  Avg loss: 0.003448
#
# Epoch 161
# -------------------------------
# loss: 0.003267  [    0/90000]
# Test Error:
#  Avg loss: 0.003436
#
# Epoch 162
# -------------------------------
# loss: 0.002942  [    0/90000]
# Test Error:
#  Avg loss: 0.003447
#
# Epoch 163
# -------------------------------
# loss: 0.003082  [    0/90000]
# Test Error:
#  Avg loss: 0.003427
#
# Epoch 164
# -------------------------------
# loss: 0.003165  [    0/90000]
# Test Error:
#  Avg loss: 0.003424
#
# Epoch 165
# -------------------------------
# loss: 0.003005  [    0/90000]
# Test Error:
#  Avg loss: 0.003439
#
# Epoch 166
# -------------------------------
# loss: 0.002989  [    0/90000]
# Test Error:
#  Avg loss: 0.003438
#
# Epoch 167
# -------------------------------
# loss: 0.003253  [    0/90000]
# Test Error:
#  Avg loss: 0.003412
#
# Epoch 168
# -------------------------------
# loss: 0.002988  [    0/90000]
# Test Error:
#  Avg loss: 0.003405
#
# Epoch 169
# -------------------------------
# loss: 0.002989  [    0/90000]
# Test Error:
#  Avg loss: 0.003393
#
# Epoch 170
# -------------------------------
# loss: 0.003396  [    0/90000]
# Test Error:
#  Avg loss: 0.003401
#
# Epoch 171
# -------------------------------
# loss: 0.003444  [    0/90000]
# Test Error:
#  Avg loss: 0.003421
#
# Epoch 172
# -------------------------------
# loss: 0.003001  [    0/90000]
# Test Error:
#  Avg loss: 0.003418
#
# Epoch 173
# -------------------------------
# loss: 0.003023  [    0/90000]
# Test Error:
#  Avg loss: 0.003492
#
# Epoch 174
# -------------------------------
# loss: 0.003185  [    0/90000]
# Test Error:
#  Avg loss: 0.003391
#
# Epoch 175
# -------------------------------
# loss: 0.003047  [    0/90000]
# Test Error:
#  Avg loss: 0.003384
#
# Epoch 176
# -------------------------------
# loss: 0.002964  [    0/90000]
# Test Error:
#  Avg loss: 0.003373
#
# Epoch 177
# -------------------------------
# loss: 0.002896  [    0/90000]
# Test Error:
#  Avg loss: 0.003370
#
# Epoch 178
# -------------------------------
# loss: 0.002765  [    0/90000]
# Test Error:
#  Avg loss: 0.003354
#
# Epoch 179
# -------------------------------
# loss: 0.003068  [    0/90000]
# Test Error:
#  Avg loss: 0.003369
#
# Epoch 180
# -------------------------------
# loss: 0.002972  [    0/90000]
# Test Error:
#  Avg loss: 0.003347
#
# Epoch 181
# -------------------------------
# loss: 0.003048  [    0/90000]
# Test Error:
#  Avg loss: 0.003359
#
# Epoch 182
# -------------------------------
# loss: 0.002991  [    0/90000]
# Test Error:
#  Avg loss: 0.003345
#
# Epoch 183
# -------------------------------
# loss: 0.003019  [    0/90000]
# Test Error:
#  Avg loss: 0.003353
#
# Epoch 184
# -------------------------------
# loss: 0.002978  [    0/90000]
# Test Error:
#  Avg loss: 0.003357
#
# Epoch 185
# -------------------------------
# loss: 0.003075  [    0/90000]
# Test Error:
#  Avg loss: 0.003348
#
# Epoch 186
# -------------------------------
# loss: 0.003097  [    0/90000]
# Test Error:
#  Avg loss: 0.003339
#
# Epoch 187
# -------------------------------
# loss: 0.003115  [    0/90000]
# Test Error:
#  Avg loss: 0.003355
#
# Epoch 188
# -------------------------------
# loss: 0.002875  [    0/90000]
# Test Error:
#  Avg loss: 0.003326
#
# Epoch 189
# -------------------------------
# loss: 0.002891  [    0/90000]
# Test Error:
#  Avg loss: 0.003343
#
# Epoch 190
# -------------------------------
# loss: 0.002738  [    0/90000]
# Test Error:
#  Avg loss: 0.003322
#
# Epoch 191
# -------------------------------
# loss: 0.003221  [    0/90000]
# Test Error:
#  Avg loss: 0.003329
#
# Epoch 192
# -------------------------------
# loss: 0.003013  [    0/90000]
# Test Error:
#  Avg loss: 0.003320
#
# Epoch 193
# -------------------------------
# loss: 0.002832  [    0/90000]
# Test Error:
#  Avg loss: 0.003327
#
# Epoch 194
# -------------------------------
# loss: 0.003293  [    0/90000]
# Test Error:
#  Avg loss: 0.003366
#
# Epoch 195
# -------------------------------
# loss: 0.002901  [    0/90000]
# Test Error:
#  Avg loss: 0.003320
#
# Epoch 196
# -------------------------------
# loss: 0.002902  [    0/90000]
# Test Error:
#  Avg loss: 0.003320
#
# Epoch 197
# -------------------------------
# loss: 0.002874  [    0/90000]
# Test Error:
#  Avg loss: 0.003307
#
# Epoch 198
# -------------------------------
# loss: 0.002909  [    0/90000]
# Test Error:
#  Avg loss: 0.003345
#
# Epoch 199
# -------------------------------
# loss: 0.003286  [    0/90000]
# Test Error:
#  Avg loss: 0.003329
#
# Epoch 200
# -------------------------------
# loss: 0.002916  [    0/90000]
# Test Error:
#  Avg loss: 0.003275
#
# Done!

# %%
model_file = f'model_files/autoencoder-facenorth_72000_samples-200ep.pt'
device = 'cuda:1'

model = AutoEncoder()
model.load_state_dict(torch.load(model_file))
model.to(device)
model.eval()

print(next(model.parameters()).device)

#seq, corr = next(iter(test_loader))
seq = next(iter(test_loader))

imshow(torchvision.utils.make_grid(seq[0]))
#imshow(corr[0])

with torch.no_grad():
    pred = model(seq.to(device))[0].cpu() # won't this have issues with a batch norm or something if you have one batch

imshow(pred)
# Out:
# cuda:0

# %% [markdown]
# ### Train an MLP to predict location from latent values

# %%
# This is dumb, but I need to remove the head direction stuff at least for now from coords

def remove_head_dir(coords_dir):
    for filename in os.listdir(coords_dir):
        filepath = os.path.join(coords_dir, filename)
        data = np.load(filepath, mmap_mode='r')
        data = np.delete(data, 2, axis=1)
        np.save(filepath, data)
        del data

remove_head_dir('data/worldone-indexed/coords')

# %%
coords_dir = 'data/worldone-indexed/coords'

for filename in os.listdir(coords_dir):
    filepath = os.path.join(coords_dir, filename)
    data = np.load(filepath, mmap_mode='r').astype(np.float32)
    np.save(filepath, data)
    del data

# %%
# Load in the coordinate data
data_dir = 'data'
target_dir_name = 'worldone-indexed'

transform = torchvision.transforms.Compose([
        torchvision.transforms.ToTensor(),
        torchvision.transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

dataset = CoordinateDataset(source_directory=data_dir, 
                            target_directory_name=target_dir_name,
                            transform=transform)

train_ratio = math.floor(len(dataset) * 0.9)
train_data, test_data = random_split(dataset, [train_ratio, len(dataset) - train_ratio])
print(f'{train_ratio} training samples')
batch_size = 10
# does it matter in this instance if you shuffle? I think you can get away with it
train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True, num_workers=2)
test_loader = DataLoader(test_data, batch_size=batch_size, shuffle=True, num_workers=2)
# Out:
# Assuming already indexed frame files in data/worldone-indexed/frames
# Assuming already indexed coords files in data/worldone-indexed/coords
# 27720 training samples

# %%
# Set up the model, which takes as input my trained predictive coder encoder and attn

latent_model_file = f'model_files/worldone_fixedhead_27720_samples.pt'
loc_predictor_file = latent_model_file[:-3] + '_predictor.pt'

latent_model = PredictiveCoder()
latent_model.load_state_dict(torch.load(latent_model_file))
latent_model.eval()
for param in latent_model.parameters():
    param.requires_grad = False

model = LocationPredictor(latent_model)
model.to(device)

num_epochs = 5
steps_per_epoch = len(train_loader)

learning_rate = 0.01
weight_decay = 0.0001

loss_fn = torch.nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9, weight_decay=weight_decay)

# %%
train_losses_file = 'logs/pred-loc-fixedhead-train.txt'
test_losses_file = 'logs/pred-loc-fixedhead-test.txt'

train_losses = []
test_losses = []

for epoch in range(num_epochs):
    print(f"Epoch {epoch+1}\n-------------------------------")
    train_loss = train(train_loader, model, loss_fn, optimizer, device)
    test_loss = test(test_loader, model, loss_fn, device)
    train_losses.append(train_loss)
    test_losses.append(test_loss)

    print(f'Epoch {epoch} train loss: {test_loss}')
    lr_scheduler.step()
    
torch.save(model.state_dict(), model_file)

with open(train_losses_file, 'w') as fp:
    for s in train_losses:
        fp.write("%s\n" % s)
        
with open(test_losses_file, 'w') as fp:
    for x in test_losses:
        fp.write("%s\n" % x)

print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 328879.500000  [    0/27720]
# loss: 61.748158  [10000/27720]
# loss: 111.687698  [20000/27720]

# %%
# checking to see if I've covered most of the space since this model is really not perfect.

import datetime

directory = 'data/'
coordinates = set()
total_len = 0
for file in os.listdir(directory):
    if file.startswith('coords_'):
        data = np.load(os.path.join(directory, file))
        # Assuming the data format in each file is [x, y, yaw]
        for line in data:
            total_len += 1
            x, z = line[0], line[1]
            coordinates.add((x, z))

print('total number of frames (more than actual sequences):', total_len) 
print(len(coordinates))
print(40*65) # minus any obstacles, but should be kinda close

full_coords = set()
for x in range(-484,-427):
    for z in range(-694, -658):
        full_coords.add((x + 0.5, z + 0.5))

#print(full_coords.difference(coordinates))
# TODO remove duplicate entries from your training data
# Out:
# total number of frames (more than actual sequences): 91143
# 1647
# 2600

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming we have two sets of data points, one for actual (ground truth) and one for predicted
# For demonstration, random points around a line y=x will be generated for actual
# and points with some added noise for predicted

np.random.seed(0) # for reproducibility

# Generate some random data for demonstration purposes
actual_x = np.linspace(-40, 40, 300)
actual_y = actual_x + np.random.normal(size=actual_x.shape) * 5  # some random noise around the line y=x

predicted_x = actual_x + np.random.normal(size=actual_x.shape) * 5  # additional noise for predicted points
predicted_y = actual_y + np.random.normal(size=actual_y.shape) * 5

# Calculate errors (distance) between actual and predicted points
errors_x = predicted_x - actual_x
errors_y = predicted_y - actual_y
errors = np.sqrt(errors_x**2 + errors_y**2)

# Create the figure and the axis
fig, ax = plt.subplots()

# Plot actual points
ax.scatter(actual_x, actual_y, color='gray', label='Actual')

# Plot predicted points
ax.scatter(predicted_x, predicted_y, color='blue', label='Predicted')

# Plot error lines
for i in range(len(actual_x)):
    ax.plot([actual_x[i], predicted_x[i]], [actual_y[i], predicted_y[i]], color='gray', linewidth=0.5)

# Set labels and title
ax.set_xlabel('x (lattice units)')
ax.set_ylabel('y (lattice units)')
ax.set_title('The predictive coder\'s latent space encodes spatial position')

# Add legend
ax.legend()

# Show the plot
plt.show()
